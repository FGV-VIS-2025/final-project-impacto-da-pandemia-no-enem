# %%
import pandas as pd
import geopandas as gpd

# %%
data = pd.read_csv("data/uf_qtd_e_notas_por_ano.csv")
data
# Out:
#      NU_ANO SG_UF_PROVA  QUANTIDADE_PESSOAS  NU_NOTA_CN  NU_NOTA_CH  \
# 0      2019          AC               27427  450.998738  484.077340
# 1      2019          AL               67407  458.818669  487.759454
# 2      2019          AM               74579  450.916203  483.940851
# 3      2019          AP               29874  450.211244  484.780699
# 4      2019          BA              287399  464.864261  495.678100
# ..      ...         ...                 ...         ...         ...
# 130    2023          RS              110735  508.906245  542.740507
# 131    2023          SC               62700  510.607536  545.735842
# 132    2023          SE               47189  485.294978  511.636634
# 133    2023          SP              409480  515.632185  548.660375
# 134    2023          TO               21612  479.928447  504.588520
#
#      NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0    502.189499  482.135192       542.539833
# 1    504.505793  500.102375       564.068717
# ...

# %%
data.to_json("GeoJSON/uf_qtd_e_notas.json", orient="records")
